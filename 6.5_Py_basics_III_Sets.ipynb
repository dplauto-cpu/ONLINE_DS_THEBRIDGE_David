# %% [markdown]
# <a href="https://colab.research.google.com/github/dplauto-cpu/ONLINE_DS_THEBRIDGE_David/blob/main/6.5_Py_basics_III_Sets.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Colecciones Python: Sets

# %% [markdown]
# ### Contenidos

# %% [markdown]
# * [Introducción](#Introducción)

# %% [markdown]
# ### Introducción
# [al indice](#Contenidos)
#
# Otra colección *bulit-in* de Python, compuesta por un conjunto de *valores*. Muy parecidos a las listas. Tienen las siguientes características:
# * **Mutables**: podemos modificarlos una vez se hayan creado
# * **No ordenado**
# * **Elementos unicos**: se compone de un conjunto de valores únicas
#
# **¿Cuándo usar sets?** Cuando estemos buscando unicidad en nuestros datos y no nos importe el orden.
#
# Te dejo por aquí [la documentación](https://docs.python.org/2/library/sets.html) para realizar consultas sobre los sets
#
# Si sintaxis es:
# >```Python
# > mi_set = {elemento1, elemento2, elemento3}
# >```
#
# Tiene una sintaxis muy parecida a la de las listas, pero en este caso no se utilizan los `{}`.

# %%
colores ={"rojo", "azul", "blanco", "naranja", "blanco"} #el set ignora los duplicados y la len es 4
print(colores, type(colores))
print(len(colores))

colores.add("magenta") #se pueden añadir colores
print(colores)

#con update se puede añadir una lista de nuevos colores
colores.update(["amarillo", "verde", "celeste", "naranja"])
print(colores)
# Out:
# {'blanco', 'azul', 'naranja', 'rojo'} <class 'set'>
# 4

# %% [markdown]
# Los elementos del set son unicos, por lo que si en la declaración, o posteriormente añadiendo elementos hubiese algún duplicado, el set lo ignoraría. Es más, cuando aplicas el `len`, muestra la cantidad de valores únicos que tiene.

# %%
colores.add("magenta") #se pueden añadir colores
print(colores)

#con update se puede añadir una lista de nuevos colores
colores.update(["amarillo", "verde", "celeste", "naranja"])
print(colores)

colores.remove("naranja") #para eliminar elementos
print(colores)

#tb son iterables
for color in colores:
  print(color)
# Out:
# {'verde', 'magenta', 'amarillo', 'celeste', 'blanco', 'azul', 'rojo'}
# {'verde', 'magenta', 'amarillo', 'celeste', 'blanco', 'azul', 'rojo', 'naranja'}
# {'verde', 'magenta', 'amarillo', 'celeste', 'blanco', 'azul', 'rojo'}
# verde
# magenta
# amarillo
# celeste
# blanco
# azul
# rojo

# %% [markdown]
# Para comprobar si dos sets tienen los mismos elementos

# %%
Set1 = {1,2,4,4,2,1,2,1,2}
Set2 = {1,2,4}
print(Set1 == Set2) #te dice que son iguales porque no cuenta los duplicados
# Out:
# True

# %%
lista_con = [100, 10, 23,23,16,32,45,10,100,23] #xa eliminar duplicados se puede pasar de set a lista y de lista a set
print(lista_con)
# print(set(lista_con))
# print(list(set(lista_con))) #aquí ya la tenemos en formato lista, sin duplicados, para asignar valores\
# y dejar de ser print:
lista_con = list(set(lista_con)) #he silenciado las ods operaciones anteriores, para que se vea mejor el cambbio
print(lista_con)
# Out:
# [100, 10, 23, 23, 16, 32, 45, 10, 100, 23]
# [32, 100, 10, 45, 16, 23]
