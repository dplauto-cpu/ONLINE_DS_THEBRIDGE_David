# %% [markdown]
# <a href="https://colab.research.google.com/github/dplauto-cpu/ONLINE_DS_THEBRIDGE_David/blob/main/Parte_4_11_Ejercicios_Python_Basisc_I_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# ## EJERCICIOS PYTHON BASICO 3:
# ## Operaciones matemáticas, comparación y booleanas

# %% [markdown]
# Completa los siguiente ejercicios, la solución completa a los mismos se publicarán en el repo del curso a lo largo del sprint. En algunos ejercicios se muestra la solución final, para que puedas comprobar que lo has hecho bien, pero lo importante es el código que generes. ¡Vaaamos, a ello...!

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
#
# ## Ejercicio 1
# Tenemos las siguientes variables:
#
# ```Python
# A = 4
# B = "Text"
# C = 4.1
# ```
#
# Comprueba:
# 1. Si A y B son equivalentes
# 2. Si A y C NO son equivalentes
# 3. Si A es mayor que C
# 4. Si C es menor o igual que A
# 5. Si B NO es equivalente a C

# %%
A = 4
B = "Text"
C = 4.1

print(A == B)
print(A != C)
print(A > C)
print(C <= A)
print(B != C)
# Out:
# False
# True
# False
# False
# True

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 2
# Crea un programa donde se recojan dos inputs del usuario, y el output del programa sea si esos inputs son iguales o no

# %%
nombre = input("Dime tu nombre: ")
procedencia = input("De donde eres: ")
print(nombre == procedencia)
# Out:
# Dime tu nombre: Felix
# De donde eres: Palencia
# False

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 3
# Mismo programa que en 2, pero en esta ocasión tienen que ser tres inputs y dos salidas. Una de las salidas que nos indique si todos son iguales, y la otra si al menos dos inputs sí que lo son

# %%
nombre = input("Dime tu nombre: ")
procedencia = input("De donde eres: ")
edad = input("Dime tu edad: ")
print(nombre == procedencia and nombre == edad)
print(procedencia == edad)
# No he entendido bien el enunciado, cada input genera una salida, entonces no entiendo como 3 generan 2
# Out:
# Dime tu nombre: Felix
# De donde eres: Palencia
# Dime tu edad: 35
# False
# False

# %% [markdown]
# ![ejercicio.png](./img/ejercicio.png)
#
# ## Ejercicio 4
# Razona sin ejecutar código el output que obtendremos de las siguientes sentencias
# 1. True and True and False
# 2. not ((True or False) and (True or False))
# 3. (False or False or False or True) and False
# 4. not False and True and not True

# %%
"""
1. False, porque True and False = False
2. False or True, depende de la segunda premisa. Si la segunda es True, la primera es False,
y viceversa, si la segunda es False, la primera es True.
3. False, porque cualquier combinación de False y False o de False is True = False
4. False, porque not False es True, luego la primera premisa es True, pero la segunda True and not True (luego False) = False
"""

# %% [markdown]
# """
# 1. False, porque True and False es False
# 2. False o True, depende de la segunda parte "o", si "o" es True, la primera es False, y viceversa si "o" es False, la primera es True
# 3. False, porque cualquier "o" False y False es False, y si el "o" es True, también es False
# 4. False, porque not False es True, luego True and True es True, pero True and not True es False
# """
