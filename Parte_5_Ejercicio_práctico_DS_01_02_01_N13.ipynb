# %% [markdown]
# <a href="https://colab.research.google.com/github/dplauto-cpu/ONLINE_DS_THEBRIDGE_David/blob/main/Parte_5_Ejercicio_pr%C3%A1ctico_DS_01_02_01_N13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## PRACTICA OBLIGATORIA: COLECCIONES Y FUNCIONES

# %% [markdown]
# * La práctica obligatoria de esta unidad consiste varios ejercicios de programación libre a completar sobre Colecciones y Funciones. Descarga este notebook en tu ordenador y trabaja en local.
# * Recuerda que debes subirla a tu repositorio personal antes de la sesión en vivo para que puntúe adecuadamente y puedas participar en dicha sesión.
# * Recuerda también que no es necesario que esté perfecta, sólo es necesario que se vea el esfuerzo.
# * Esta práctica se resolverá en la sesión en vivo correspondiente y la solución se publicará en el repo del curso.

# %% [markdown]
# ### Contenidos

# %% [markdown]
# ## Ejercicio 1
# Eleva todos los elementos de la lista al cuadrado
# > ```ejer_2 = [1,2,3,4,5]```

# %%
ejer_2 = [1,2,3,4,5]
for i in ejer_2:
    print(i**2)
# Out:
# 1
# 4
# 9
# 16
# 25

# %% [markdown]
# ## Ejercicio 2
# Haz un programa que detecte todos los duplicados de un elemento en una lista:
# * Utiliza una variable duplicado para asignarle el valor del elemento del que queremos encontrar todos sus duplicados.
# * El programa debe devolver todos los índices de los elementos duplicados.
# * Aplícalo para encontrar los duplicados de "un", "es" y "binario" de:
#
# >```ejer_3 = ["Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular", "a", "veces", "no", "es", "ni", "binario"]```

# %%
ejer_3 = ["Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular", "a", \
          "veces", "no", "es", "ni", "binario"]
          
todos = set()
duplicados = set()
for i in ejer_3:
    if i in todos:
        duplicados.add(i)
    elif "un" in todos:
        duplicados.add("un")
    else:
        todos.add(i)
print(list(duplicados))
# Out:
# ['un', 'binario', 'es']

# %% [markdown]
# ## Ejercicio 3
# 1. ¿Cuántas veces se repite el 3 en la siguiente tupla?
# 2. Crea una tupla nueva con los elementos desde la posicion 5 a la 10.
# 3. ¿Cuántos elementos tiene la tupla `ejer_3`?
# > ```ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)```

# %%
ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)
print(ejer_9.count(3))
nuevo = ejer_9[4:10]
print(nuevo)
print(len(ejer_3))
# Out:
# 7
# (19, 3, 29, 45, 67, 78)
# 16

# %% [markdown]
# ## Ejercicio 4
# Comprueba si el numero 60 esta en la tupla del ejercicio 3

# %%
print(ejer_9.index(60))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 print(ejer_9.index(60))
#
# NameError: name 'ejer_9' is not defined

# %% [markdown]
# ## Ejercicio 5
# 1. Convierte la tupla del ejercicio 3 en una lista
# 2. Convierte la tupla del ejercicio 3 en un set
# 3. Convierte la tupla del ejercicio 3 en un diccionario. Usa también los indices

# %%
ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)
print(ejer_9)
print(list(ejer_9))
print(set(ejer_9))

ejer_9 = (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)
diccionario9 = {ejer_9[i] : ejer_9[+1] for i in range(0,len(ejer_9))}
print(diccionario9)
# Esta me ha costado horrores, no sabía (y sigo sin intender) que se puediera meter un for en la línea, sin tab aparte, he llegado por casualidad
# Out:
# (3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7)
# [3, 20, 3, 47, 19, 3, 29, 45, 67, 78, 90, 3, 3, 5, 2, 4, 7, 9, 4, 2, 4, 3, 3, 4, 6, 7]
# {2, 3, 67, 5, 4, 7, 6, 9, 45, 78, 47, 19, 20, 90, 29}
# {3: 20, 20: 20, 47: 20, 19: 20, 29: 20, 45: 20, 67: 20, 78: 20, 90: 20, 5: 20, 2: 20, 4: 20, 7: 20, 9: 20, 6: 20}

# %% [markdown]
# ## Ejercicio 6
# Multiplica todos los valores del diccionario
# > ```ejer_6 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}```

# %%
ejer_6 = {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}
valor_mul = 1

for clave in ejer_6:
    ejer_6[clave] *= valor_mul

print(ejer_6)
 # Otro que me ha costado la del horror, por favor en la clase presencial haced un repaso profundo de los bucles
# Out:
# {1: 11, 2: 22, 3: 33, 4: 44, 5: 55}

# %% [markdown]
# ## Ejercicio 7
#
# 1. Crea un diccionario que describa un libro, con los siguientes campos o claves: "titulo","autor","idioma original","año de publicación".
# 2. Crea un a lista, llamada librería.
# 3. Añade cuatro libros a tu elección a la librería.

# %%
biblioteca = {
    "título" : "",
    "autor" : "",
    "idioma original" : "", 
    "año de publicación" : "",}
print(biblioteca, type(biblioteca))

libreria = []
print(libreria, type(libreria))

titulos = ["Momo", "Crimen y Castigo", "Niebla", "Las aventuras de Sherlock Holmes"]
autores = ["Michael Ende", "Fiodor Dostoyevski", "Miguel de Unamuno", " Arthur Conan Doyle"]
idioma = ["aleman", "ruso", "español", "inglés"]
ano_pub = [972, 1867, 1892, 194]
libreria.extend(titulos + autores + idioma + ano_pub)
print(libreria)
# Out:
# {'título': '', 'autor': '', 'idioma original': '', 'año de publicación': ''} <class 'dict'>
# [] <class 'list'>
# ['Momo', 'Crimen y Castigo', 'Niebla', 'Las aventuras de Sherlock Holmes', 'Michael Ende', 'Fiodor Dostoyevski', 'Miguel de Unamuno', ' Arthur Conan Doyle', 'aleman', 'ruso', 'español', 'inglés', 972, 1867, 1892, 194]

# %% [markdown]
# ## Ejercicio 8
# Modifica los valores del idioma de todos los libros del ejercicio anterior para que sea "esperanto"

# %%
idioma[0:] = ["esperanto"]
print(idioma)
# Out:
# ['esperanto']

# %% [markdown]
# ## Ejercicio 9
# 1. Escribe un programa que dada una variable titulo busque los libros que hay en la librería con ese título. Si no se encuentra debe devolver el mensaje `Ese no lo tengo, ¿mola?`
# 2. Pruena que el programa con uno de tus libros y con otro que no contenga tu librería.

# %%
if titulos in libreria:
    print("Existe")
else:
    print("Este no lo tengo, ¿mola?")
# Out:
# Este no lo tengo, ¿mola?

# %% [markdown]
# ## Ejercicio 10
# Convierte el programa del ejercicio 2 en una función al que se le pase el valor a buscar como un argumento posicional

# %%
ejer_3 = ["Un", "árbol", "binario", "es", "una", "estructura", "de", "un", "tipo", "particular", "a", "veces", "no", "es", "ni", "binario"]

print(ejer_3, type(ejer_3))

def busca(un, es, binario):
    return un + es + binario

print(busca("un", "binario", "es"))
# Out:
# ['Un', 'árbol', 'binario', 'es', 'una', 'estructura', 'de', 'un', 'tipo', 'particular', 'a', 'veces', 'no', 'es', 'ni', 'binario'] <class 'list'>
# unbinarioes

# %% [markdown]
# ## Ejercicio 11
# Convierte el programa del ejercicio 9 en una función al que se le pasen como argumentos la librería, posicional, y el título, argumento keyword con valor "ninguno", por defecto.

# %%
if titulos in libreria:
    print("Existe")
else:
    print("Este no lo tengo, ¿mola?")

def libros(libreria, titulos = None):
    return (libreria, titulos)

busco = (libreria, titulos)
print(busco)
# Out:
# Este no lo tengo, ¿mola?
# (['Momo', 'Crimen y Castigo', 'Niebla', 'Las aventuras de Sherlock Holmes', 'Michael Ende', 'Fiodor Dostoyevski', 'Miguel de Unamuno', ' Arthur Conan Doyle', 'aleman', 'ruso', 'español', 'inglés', 972, 1867, 1892, 194], ['Momo', 'Crimen y Castigo', 'Niebla', 'Las aventuras de Sherlock Holmes'])

# %% [markdown]
# ## Ejercicio 12
# Solicitar al usuario que ingrese su dirección email. Imprimir un mensaje indicando si la dirección es válida o no, valiéndose de una función para decidirlo. Una dirección se considerará válida si contiene el símbolo "@".

# %%
email = "nombreusuario@correo.com"
if "@" in email:
    print("dirección de correo válida")
else:
    print("incorrecta, falta símbolo @")

cuenta =input("introduzca su email:")
# Out:
# dirección de correo válida

# %% [markdown]
# ## Ejercicio 13
# Escribe una función que compruebe si un DNI es válido, devolviendo `True` en caso afirmativo.
# En primer lugar, el DNI debe tener entre 7 y 8 dígitos numéricos.
# Para saber si la letra del DNI es correcta puedes utilizar el siguiente fragmento de código:
# >```Python
# >DNI= 55555555
# >palabra='TRWAGMYFPDXBNJZSQVHLCKE'
# >print('La letra del DNI es: ', palabra[DNI%23])
# >````

# %%
DNI = 55555555
palabra='TRWAGMYFPDXBNJZSQVHLCKE'
i = 0
lista_palabras = list(palabra)


def DNI_valido(DNI):
 while DNI != 0:
  i = (i + 1)
  return i == 7 or i == 8




print('La letra del DNI es: ', palabra[DNI%23])

# Lo siento, me rindo, no soy capaz de hacerlo, intuyo que hay que usar el bucle while pero no sé cómo
# y lo mismo con la letra, intuyo que hay usar el método .index pero tampoco soy capaz de integrar eso en lo anterior
# Out:
# <class 'list'>
# La letra del DNI es:  K
