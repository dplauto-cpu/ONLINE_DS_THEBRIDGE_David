# %% [markdown]
# "En lugar de la Mancha"
# "Veinte años después el coronel Aureliano Buendía aguardaba el pelotón de fusilamiento"

# %% [markdown]
# # "En un lugar de la Mancha"
# ## "Veinte años después los tres mosqueteros estaban más rellenitos"

# %% [markdown]
# 1. Primer Elemento
# 2. Segundo Elemento

# %% [markdown]
# * Elemento 1
# + Elemento 2
# - Elemento 3
# * Menudo elemento

# %% [markdown]
# ```Python
# variable = "Esto es una variable"
# ```

# %% [markdown]
# [enlace a Google](http://www.google.es)
#
# [un enlace][mi_web]
#
# [web][mi_web]
#
# [mi_web]:http://www.google.es
#
# [enlace](#"En-un-lugar-de-la-Mancha")
# [20](#"Veinte-años-después-los-mosqueteros-estaban-más-rellenitos)

# %% [markdown]
# ![Gato Naranja Japonés]("C:\Users\David\Pictures\Saved Pictures\DSCF1722 (2017_12_03 10_10_28 UTC).JPG")
